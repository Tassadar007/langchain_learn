# %%
# %pip install llama-index -U
# Out:
# Requirement already satisfied: llama-index in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (0.11.7)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.3.1)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.7 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.11.7)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.4 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.4)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.3 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.2.1)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.1->llama-index) (1.40.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (3.10.3)
# Requirement already satisfied: dataclasses-json in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2024.6.1)
# Requirement already satisfied: httpx in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (3.3)
# Requirement already satisfied: numpy<2.0.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2.8.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-core<0.12.0,>=0.11.7->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.0.17)
# Requirement already satisfied: pandas in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.3.0->llama-index) (0.5.2)
# Requirement already satisfied: click in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2024.7.24)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.9.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.0.5)
# Requirement already satisfied: idna in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.7)
# Requirement already satisfied: sniffio in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.7->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.1->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.7->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.12.0,>=0.11.7->llama-index) (24.1)
# Requirement already satisfied: six>=1.5 in /Users/yanglinshuo/anaconda3/envs/streamlit/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.core import (
    VectorStoreIndex,
    SimpleKeywordTableIndex,
    SimpleDirectoryReader,
)
from llama_index.core import SummaryIndex
from llama_index.core.schema import IndexNode
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.llms.openai import OpenAI
from llama_index.core.callbacks import CallbackManager

# %%
os.environ["OPENAI_API_KEY"] = ""
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
wiki_titles = [
    "Serie A",
    "Premier League",
    "La Liga",
    "Ligue 1",
    "Bundesliga",
]

# %%
from pathlib import Path
import requests
for title in wiki_titles:
    params = requests.get(
        "https://en.wikipedia.org/w/api.php",
        params={
            "action": "query",
            "format": "json",
            "titles": title,
            "prop": "extracts",
            "explaintext": True,
        },
    ).json()
    page = next(iter(params["query"]["pages"].values()))
    wiki_text = page["extract"]
    data_path = Path("data")
    if not data_path.exists():
        Path.mkdir(data_path)
    with open(data_path / f"{title}.txt", "w") as f:
        f.write(wiki_text)

# %%
leagues_docs = {}
for wiki_title in wiki_titles:
    leagues_docs[wiki_title] = SimpleDirectoryReader(
        input_files=[f"data/{wiki_title}.txt"]
    ).load_data()

# %%
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings

Settings.llm = OpenAI(temperature=0, model="gpt-4o-mini")
Settings.embed_model = OpenAIEmbedding(model="text-embedding-ada-002")

# %%
from llama_index.agent.openai import OpenAIAgent
from llama_index.core import load_index_from_storage, StorageContext
from llama_index.core.node_parser import SentenceSplitter
import os

node_parser = SentenceSplitter()

# Build agents dictionary
agents = {}
query_engines = {}

# this is for the baseline
all_nodes = []

for idx, wiki_title in enumerate(wiki_titles):
    nodes = node_parser.get_nodes_from_documents(leagues_docs[wiki_title])
    all_nodes.extend(nodes)

    if not os.path.exists(f"./data/{wiki_title}"):
        # build vector index
        vector_index = VectorStoreIndex(nodes)
        vector_index.storage_context.persist(
            persist_dir=f"./data/{wiki_title}"
        )
    else:
        vector_index = load_index_from_storage(
            StorageContext.from_defaults(persist_dir=f"./data/{wiki_title}"),
        )

    # build summary index
    summary_index = SummaryIndex(nodes)
    # define query engines
    vector_query_engine = vector_index.as_query_engine(llm=Settings.llm)
    summary_query_engine = summary_index.as_query_engine(llm=Settings.llm)

    # define tools
    query_engine_tools = [
        QueryEngineTool(
            query_engine=vector_query_engine,
            metadata=ToolMetadata(
                name="vector_tool",
                description=(
                    "Useful for questions related to specific aspects of"
                    f" {wiki_title} (e.g. the history, teams "
                    "and performance in EU, or more)."
                ),
            ),
        ),
        QueryEngineTool(
            query_engine=summary_query_engine,
            metadata=ToolMetadata(
                name="summary_tool",
                description=(
                    "Useful for any requests that require a holistic summary"
                    f" of EVERYTHING about {wiki_title}. For questions about"
                    " more specific sections, please use the vector_tool."
                ),
            ),
        ),
    ]

    # build agent
    function_llm = OpenAI(model="gpt-4o-mini")
    agent = OpenAIAgent.from_tools(
        query_engine_tools,
        llm=function_llm,
        verbose=True,
        system_prompt=f"""\
You are a specialized agent designed to answer queries about {wiki_title}.
You must ALWAYS use at least one of the tools provided when answering a question; do NOT rely on prior knowledge.\
""",
    )

    agents[wiki_title] = agent
    query_engines[wiki_title] = vector_index.as_query_engine(
        similarity_top_k=2
    )

# %%
# define tool for each document agent
all_tools = []
for wiki_title in wiki_titles:
    wiki_summary = (
        f"This content contains Wikipedia articles about {wiki_title}. Use"
        f" this tool if you want to answer any questions about {wiki_title}.\n"
    )
    doc_tool = QueryEngineTool(
        query_engine=agents[wiki_title],
        metadata=ToolMetadata(
            name=f"tool_{wiki_title.replace(' ', '_')}",
            description=wiki_summary,
        ),
    )
    all_tools.append(doc_tool)

# %%
# define an "object" index and retriever over these tools
from llama_index.core import VectorStoreIndex
from llama_index.core.objects import ObjectIndex, SimpleToolNodeMapping

tool_mapping = SimpleToolNodeMapping.from_objects(all_tools)
obj_index = ObjectIndex.from_objects(
    all_tools,
    tool_mapping=tool_mapping,
    index_cls=VectorStoreIndex,
)

# %%
from llama_index.agent.openai import OpenAIAgent

top_agent = OpenAIAgent.from_tools(
    tool_retriever=obj_index.as_retriever(similarity_top_k=3),
    system_prompt=""" \
You are an agent designed to answer queries about the European top football leagues.
Please always use the tools provided to answer a question. Do not rely on prior knowledge.\

""",
    verbose=True,
)

# %%
base_index = VectorStoreIndex(all_nodes)
base_query_engine = base_index.as_query_engine(similarity_top_k=4)

# %%
# should use Boston agent -> vector tool
response = top_agent.query("Tell me about the history and UCL performance of La Liga")
print(response)
# Out:
# Added user message to memory: Tell me about the history and UCL performance of La Liga
# === Calling Function ===
# Calling function: tool_La_Liga with args: {"input": "history"}
# Added user message to memory: history
# === Calling Function ===
# Calling function: summary_tool with args: {"input":"history of La Liga"}
# Got output: La Liga, officially known as LaLiga EA Sports since 2023, was founded in April 1928 when José María Acha proposed the idea of a national league in Spain. The first season commenced in 1929 with ten teams, including notable clubs like Barcelona, Real Madrid, and Athletic Bilbao.
#
    "Please compare Premier League and La Liga in terms of history and UCL performance"
)
print(str(response))
# Out:
# ### History of La Liga
#
# La Liga, officially known as LaLiga EA Sports since 2023, was founded in April 1928 when José María Acha proposed the idea of a national league in Spain. The inaugural season commenced in 1929 with ten teams, including notable clubs like Barcelona, Real Madrid, and Athletic Bilbao.
#
# - **1930s**: Athletic Bilbao emerged as a dominant force, winning multiple titles, while Barcelona won the first league title. The league was suspended during the Spanish Civil War, and in 1937, a separate Mediterranean League was formed, with Barcelona as the champion.
#
# - **1940s**: After the war, Atlético Madrid, Valencia, and Barcelona became the strongest clubs.
#
# - **1950s**: The rise of both FC Barcelona and Real Madrid occurred, with each club winning four titles during the decade. Real Madrid began a period of dominance in the 1960s and 1970s, winning 14 titles.
#
# - **1980s**: Real Madrid continued its success, alongside the emergence of Basque clubs like Real Sociedad and Athletic Bilbao.
#
# - **1990s**: Barcelona, under Johan Cruyff, formed the "Dream Team" and won several titles, while Real Madrid and Atlético Madrid also had their moments of glory.
#
# - **2000s**: Barcelona and Real Madrid dominated, with Valencia also winning titles.
#
# - **2010s**: Intense competition featured Barcelona, Real Madrid, and Atlético Madrid frequently battling for the championship. Atlético Madrid broke the duopoly by winning the title in 2013-14.
#
# - **2020s**: Atlético Madrid won the 2020-21 season, followed by Real Madrid and Barcelona winning subsequent titles. The league underwent a rebranding in 2023, adopting a new logo and sponsorship. La Liga has been known for its competitive nature and has produced some of the most successful clubs in European football.
#
# ### UCL Performance of La Liga
#
# La Liga clubs have a distinguished history in the UEFA Champions League, with Real Madrid, Barcelona, and Atlético Madrid being particularly successful. These teams, along with Sevilla and Valencia, are among the few Spanish clubs to have won five or more international trophies.
#
# - In the **2005–06 season**, La Liga became the first league to have its clubs win both the Champions League and UEFA Cup in the same season, a remarkable achievement that has been repeated in subsequent years.
#
# - **Real Madrid** has been especially dominant, winning their Champions League titles in several seasons, including their tenth in 2014 and their thirteenth in 2018.
#
# - In **2015**, La Liga made history by entering five teams into the Champions League group stage, highlighting the league's strength and competitiveness on the European stage.
#
# Overall, La Liga has established itself as one of the top leagues in Europe, both in terms of domestic competition and international success.

# %%
response_top = top_agent.query("Please compare Premier League and La Liga in terms of history and UCL performance")
print(response)
# Out:
# Added user message to memory: Please compare Premier League and La Liga in terms of history and UCL performance
# === Calling Function ===
# Calling function: tool_Premier_League with args: {"input": "history and UEFA Champions League performance"}
# Added user message to memory: history and UEFA Champions League performance
# === Calling Function ===
# Calling function: summary_tool with args: {"input": "history of the Premier League"}
# Got output: The Premier League's history began in the late 1980s when English football faced significant challenges, including deteriorating stadium conditions and a ban on English clubs in European competitions due to the Heysel Stadium disaster. By the early 1990s, the situation began to improve, highlighted by England's semi-final run in the 1990 FIFA World Cup and the lifting of the European ban.
#
# In 1991, a proposal for a new league emerged, leading to the signing of the Founder Members Agreement on July 17, 1991. This agreement established the FA Premier League, which was formed on May 27, 1992, as a limited company independent from the Football Association and the Football League. The inaugural season kicked off in 1992-93 with 22 clubs, and Manchester United won the first title, marking the beginning of their dominance in the league.
#
# Throughout the 1990s, Manchester United established themselves as the leading team, winning seven of the first nine titles. The late 1990s saw Arsenal emerge as a strong competitor, leading to a duopoly between the two clubs.
#
# The 2000s introduced the "Big Four" era, with Arsenal, Chelsea, Liverpool, and Manchester United dominating the league. Chelsea broke the duopoly by winning the title in 2004-05, and Arsenal famously completed the 2003-04 season unbeaten, earning the nickname "The Invincibles."
#
# In the 2010s, the league evolved into the "Big Six" with the inclusion of Manchester City and Tottenham Hotspur. Leicester City's remarkable title win in the 2015-16 season highlighted the league's unpredictability.
#
# The 2020s have seen Manchester City achieve significant success, including winning four consecutive titles from 2020-2024. The league has also adapted to modern challenges, such as the introduction of video assistant referees (VAR) and addressing issues of governance and transparency.
#
# Overall, the Premier League has transformed into the most-watched sports league globally, with a rich history marked by competitive dynamics, financial growth, and evolving club structures.
# ========================
#
# === Calling Function ===
# Calling function: vector_tool with args: {"input": "Premier League teams UEFA Champions League performance"}
# Got output: English clubs have achieved significant success in the UEFA Champions League, winning a total of 15 titles and finishing as runners-up in 11 finals. This places them behind Spanish clubs, which have won 20 titles and lost 11 finals. The performance of English clubs in this top-tier competition highlights their competitiveness on the European stage.
# ========================
#
# Got output: ### History of the Premier League
#
# The Premier League's history began in the late 1980s when English football faced significant challenges, including deteriorating stadium conditions and a ban on English clubs in European competitions due to the Heysel Stadium disaster. By the early 1990s, the situation began to improve, highlighted by England's semi-final run in the 1990 FIFA World Cup and the lifting of the European ban.
#
# In 1991, a proposal for a new league emerged, leading to the signing of the Founder Members Agreement on July 17, 1991. This agreement established the FA Premier League, which was formed on May 27, 1992, as a limited company independent from the Football Association and the Football League. The inaugural season kicked off in 1992-93 with 22 clubs, and Manchester United won the first title, marking the beginning of their dominance in the league.
#
# Throughout the 1990s, Manchester United established themselves as the leading team, winning seven of the first nine titles. The late 1990s saw Arsenal emerge as a strong competitor, leading to a duopoly between the two clubs.
#
# The 2000s introduced the "Big Four" era, with Arsenal, Chelsea, Liverpool, and Manchester United dominating the league. Chelsea broke the duopoly by winning the title in 2004-05, and Arsenal famously completed the 2003-04 season unbeaten, earning the nickname "The Invincibles."
#
# In the 2010s, the league evolved into the "Big Six" with the inclusion of Manchester City and Tottenham Hotspur. Leicester City's remarkable title win in the 2015-16 season highlighted the league's unpredictability.
#
# The 2020s have seen Manchester City achieve significant success, including winning four consecutive titles from 2020-2024. The league has also adapted to modern challenges, such as the introduction of video assistant referees (VAR) and addressing issues of governance and transparency.
#
# Overall, the Premier League has transformed into the most-watched sports league globally, with a rich history marked by competitive dynamics, financial growth, and evolving club structures.
#
# ### UEFA Champions League Performance
#
# English clubs have achieved significant success in the UEFA Champions League, winning a total of 15 titles and finishing as runners-up in 11 finals. This places them behind Spanish clubs, which have won 20 titles and lost 11 finals. The performance of English clubs in this top-tier competition highlights their competitiveness on the European stage.
# ========================
#
# === Calling Function ===
# Calling function: tool_La_Liga with args: {"input": "history and UEFA Champions League performance"}
